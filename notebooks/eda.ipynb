# %% [markdown]
# # California Housing Price Prediction — Exploratory Data Analysis
#
# This notebook explores the California housing dataset, performs data cleaning, feature engineering,
# and generates visualizations saved to `outputs/figures/`.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT))

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from src.utils import load_data, save_data_understanding_report, FIGURES_DIR
from src.preprocessing import create_clean_dataframe
from src.feature_engineering import engineer_features
from src.visualization import generate_all_eda_figures

sns.set_theme(style='whitegrid')
# %matplotlib inline

# %% [markdown]
# ## 1. Dataset Overview

# %%
raw_df = load_data()
print('Shape:', raw_df.shape)
print('\nColumns:', raw_df.columns.tolist())
print('\nDtypes:\n', raw_df.dtypes)
print('\nMissing values:\n', raw_df.isnull().sum())
print('\nDuplicates:', raw_df.duplicated().sum())
raw_df.head()
# Out:
# Shape: (20640, 10)
#
# Columns: ['longitude', 'latitude', 'housing_median_age', 'total_rooms', 'total_bedrooms', 'population', 'households', 'median_income', 'median_house_value', 'ocean_proximity']
#
# Dtypes:
#  longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# ocean_proximity        object
# dtype: object
#
# Missing values:
#  longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64
#
# Duplicates: 0
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# ...

# %%
report_path = save_data_understanding_report()
print(f'Report saved to: {report_path}')
raw_df.describe(include='all').T
# Out:
# Report saved to: /Users/selam/Desktop/qiyas_group_work/IDAE-Sec-4-Group-2-Assignment/outputs/reports/data_understanding.md
#                       count unique        top  freq           mean  \
# longitude           20640.0    NaN        NaN   NaN    -119.569704
# latitude            20640.0    NaN        NaN   NaN      35.631861
# housing_median_age  20640.0    NaN        NaN   NaN      28.639486
# total_rooms         20640.0    NaN        NaN   NaN    2635.763081
# total_bedrooms      20433.0    NaN        NaN   NaN     537.870553
# population          20640.0    NaN        NaN   NaN    1425.476744
# households          20640.0    NaN        NaN   NaN      499.53968
# median_income       20640.0    NaN        NaN   NaN       3.870671
# median_house_value  20640.0    NaN        NaN   NaN  206855.816909
# ocean_proximity       20640      5  <1H OCEAN  9136            NaN
#
#                               std      min       25%       50%       75%  \
# ...

# %% [markdown]
# ## 2. Data Cleaning & Feature Engineering

# %%
cleaned = create_clean_dataframe(raw_df)
engineered = engineer_features(cleaned)
print('Cleaned shape:', engineered.shape)
engineered.head()
# Out:
# Cleaned shape: (20640, 12)
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
#
#   houseAgeLabel  valuePerRoom
# ...

# %% [markdown]
# ## 3. House Value Distribution

# %%
from src.visualization import plot_price_distribution
plot_price_distribution(engineered)
# Out:
# PosixPath('/Users/selam/Desktop/qiyas_group_work/IDAE-Sec-4-Group-2-Assignment/outputs/figures/house_value_distribution.png')

# %% [markdown]
# ## 4. Housing Age Distribution

# %%
from src.visualization import plot_age_distribution
plot_age_distribution(engineered)
# Out:
# PosixPath('/Users/selam/Desktop/qiyas_group_work/IDAE-Sec-4-Group-2-Assignment/outputs/figures/house_age_distribution.png')

# %% [markdown]
# ## 5. Correlation Heatmap

# %%
from src.visualization import plot_correlation_heatmap
plot_correlation_heatmap(engineered)
# Out:
# PosixPath('/Users/selam/Desktop/qiyas_group_work/IDAE-Sec-4-Group-2-Assignment/outputs/figures/correlation_heatmap.png')

# %% [markdown]
# ## 6. Geographical Scatter Plot

# %%
from src.visualization import plot_geographical_scatter
plot_geographical_scatter(engineered)
# Out:
# PosixPath('/Users/selam/Desktop/qiyas_group_work/IDAE-Sec-4-Group-2-Assignment/outputs/figures/geographical_scatter.png')

# %% [markdown]
# ## 7. Income vs House Value

# %%
from src.visualization import plot_scatter
plot_scatter(engineered, 'median_income', 'median_house_value', 'Income vs House Value', 'income_vs_value')
# Out:
# PosixPath('/Users/selam/Desktop/qiyas_group_work/IDAE-Sec-4-Group-2-Assignment/outputs/figures/income_vs_value.png')

# %% [markdown]
# ## 8. Pairplot

# %%
from src.visualization import plot_pairplot
plot_pairplot(engineered)
# Out:
# PosixPath('/Users/selam/Desktop/qiyas_group_work/IDAE-Sec-4-Group-2-Assignment/outputs/figures/pairplot.png')

# %% [markdown]
# ## 9. Ocean Proximity Distribution

# %%
from src.visualization import plot_ocean_proximity_distribution
plot_ocean_proximity_distribution(engineered)
# Out:
# PosixPath('/Users/selam/Desktop/qiyas_group_work/IDAE-Sec-4-Group-2-Assignment/outputs/figures/ocean_proximity_distribution.png')

# %% [markdown]
# ## 10. Average Value by Ocean Proximity

# %%
from src.visualization import plot_avg_value_by_ocean_proximity
plot_avg_value_by_ocean_proximity(engineered)
# Out:
# PosixPath('/Users/selam/Desktop/qiyas_group_work/IDAE-Sec-4-Group-2-Assignment/outputs/figures/avg_value_by_ocean_proximity.png')

# %% [markdown]
# ## 11. Generate All EDA Figures

# %%
paths = generate_all_eda_figures(engineered)
print(f'Saved {len(paths)} figures to {FIGURES_DIR}')
# Out:
# Saved 8 figures to /Users/selam/Desktop/qiyas_group_work/IDAE-Sec-4-Group-2-Assignment/outputs/figures
